# %%
import pandas as pd

# %%
dados_dias =pd.read_csv('Dados/dias_final_de_semana.csv',sep = ';')

# %%
dados_dias.head(5)
# Out:
#    quantidade_de_dias
# 0                   8
# 1                   8
# 2                  10
# 3                   8
# 4                   9

# %%
import seaborn as sns
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from '/home/estevaolins/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py'>

# %%
sns
# Out:
# <module 'seaborn' from '/home/estevaolins/anaconda3/lib/python3.9/site-packages/seaborn/__init__.py'>

# %%
sns.set_palette('Accent')
sns.set_style('darkgrid')
ax = sns.lineplot(x ='quantidade_de_dias', y ='quantidade_de_dias', data = dados_dias)
ax.figure.set_size_inches(12,6)
ax.set_title('Dias da Semana')
ax.set_xlabel('quantidade_de_dias', fontsize = '14')
ax.set_ylabel('quantidade_de_dias', fontsize = '7')
# Out:
# Text(0, 0.5, 'quantidade_de_dias')
